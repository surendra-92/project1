# %%
import pandas as pd
df = pd.read_csv('D:/Internship Data Analyst Apr 2025/Project/healthcare_dataset.csv')
df
# Out:
#        Patient_ID   Age  Gender Insurance_Type Chronic_Disease  \
# 0           75763  93.0    Male       Medicare           False
# 1           84945  52.0    Male      Uninsured           False
# 2           88559   8.0    Male       Medicare            True
# 3           72217   5.0   Other       Medicare           False
# 4           44071  76.0    Male      Uninsured            True
# ...           ...   ...     ...            ...             ...
# 49995       16333  48.0  Female            NaN            True
# 49996       11153   5.0   Other       Medicaid            True
# 49997       15966  92.0  Female      Uninsured           False
# 49998       41988  53.0    Male       Medicaid           False
# 49999       93110  13.0  Female        Private           False
#
#       Mental_Health_Status Employment_Status  Education_Level  \
# 0                     True           Student  Advanced Degree
# 1                    False          Employed          College
# ...

# %%
#Clean columns names
df.columns = df.columns.str.strip().str.lower()
df
# Out:
#        patient_id   age  gender insurance_type chronic_disease  \
# 0           75763  93.0    Male       Medicare           False
# 1           84945  52.0    Male      Uninsured           False
# 2           88559   8.0    Male       Medicare            True
# 3           72217   5.0   Other       Medicare           False
# 4           44071  76.0    Male      Uninsured            True
# ...           ...   ...     ...            ...             ...
# 49995       16333  48.0  Female            NaN            True
# 49996       11153   5.0   Other       Medicaid            True
# 49997       15966  92.0  Female      Uninsured           False
# 49998       41988  53.0    Male       Medicaid           False
# 49999       93110  13.0  Female        Private           False
#
#       mental_health_status employment_status  education_level  \
# 0                     True           Student  Advanced Degree
# 1                    False          Employed          College
# ...

# %%
#null values find 
print(df.isnull().sum())
# Out:
# patient_id                    0
# age                        5076
# gender                     4906
# insurance_type             4991
# chronic_disease            4967
# mental_health_status       5038
# employment_status          5063
# education_level           16256
# transportation_access      4987
# distance_from_facility     5017
# area_type                  4984
# booking_date                  0
# appointment_date              0
# appointment_outcome        4958
# dtype: int64

# %%
# drop null value 
df = df.dropna(subset=['age','gender','insurance_type','chronic_disease','mental_health_status',
'employment_status',        
'education_level',           
'transportation_access',    
'distance_from_facility',     
'area_type','appointment_outcome'])
print(df.isnull().sum())
# Out:
# patient_id                0
# age                       0
# gender                    0
# insurance_type            0
# chronic_disease           0
# mental_health_status      0
# employment_status         0
# education_level           0
# transportation_access     0
# distance_from_facility    0
# area_type                 0
# booking_date              0
# appointment_date          0
# appointment_outcome       0
# dtype: int64

# %%
df
# Out:
#        patient_id   age  gender insurance_type chronic_disease  \
# 0           75763  93.0    Male       Medicare           False
# 1           84945  52.0    Male      Uninsured           False
# 2           88559   8.0    Male       Medicare            True
# 3           72217   5.0   Other       Medicare           False
# 4           44071  76.0    Male      Uninsured            True
# ...           ...   ...     ...            ...             ...
# 49995       16333  48.0  Female            NaN            True
# 49996       11153   5.0   Other       Medicaid            True
# 49997       15966  92.0  Female      Uninsured           False
# 49998       41988  53.0    Male       Medicaid           False
# 49999       93110  13.0  Female        Private           False
#
#       mental_health_status employment_status  education_level  \
# 0                     True           Student  Advanced Degree
# 1                    False          Employed          College
# ...

# %%
df.drop(['education_level'], axis=1 , inplace= True)
df
# Out:
#        patient_id    age  gender insurance_type chronic_disease  \
# 0           75763   93.0    Male       Medicare           False
# 10          94722   76.0  Female       Medicare            True
# 11          18645   18.0    Male        Private           False
# 13          21727    6.0    Male        Private            True
# 20          46269  100.0    Male       Medicaid           False
# ...           ...    ...     ...            ...             ...
# 49989       51041   50.0    Male       Medicare            True
# 49990       75773   75.0  Female       Medicare           False
# 49991       11154    8.0  Female       Medicare            True
# 49993       91361   57.0  Female        Private            True
# 49998       41988   53.0    Male       Medicaid           False
#
#       mental_health_status transportation_access  distance_from_facility  \
# 0                     True                  True               37.785038
# ...

# %%
#Train Decision tree Model
